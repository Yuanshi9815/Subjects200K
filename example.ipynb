# %%
from dataset import Subjects200KDataset
import random

# %%
subjects200k = Subjects200KDataset(enable_filter=True)

# %%
len(subjects200k)
# Out:
# 119967

# %%
item = random.choice(subjects200k)
print(f"Instance: {item['instance']}")
print(f"Description1: {item['description1']}")
print(f"Description2: {item['description2']}")
item["image_pair"]
# Out:
# Instance: A hot beverage brewed from roasted beans.
# Description1: Seated on a picnic bench in a vibrant park, surrounded by lush greenery and families enjoying the weekend, it exudes warmth amid the lively, sunlit setting.
# Description2: Against a pristine white background in a professional studio, uniform lighting casts no shadows, allowing this item's dark, glossy liquid and thick, aromatic steam to take center stage in a three-quarter view angle.
# <PIL.Image.Image image mode=RGB size=1024x512>

# %%
item = random.choice(subjects200k.dataset1)
print(f"Instance: {item['instance']}")
print(f"Description1: {item['description1']}")
print(f"Description2: {item['description2']}")
item["image_pair"]
# Out:
# Instance: Dingo
# Description1: A dingo is captured in a lush Australian savanna. The photo is taken from a side profile at a low angle to emphasize the dingo's agile stance as it stands alertly on the rugged terrain. The late afternoon sun casts a warm, golden hue, highlighting the dingo's sandy coat against the verdant backdrop of eucalyptus trees. In the far distance, a range of low-lying hills fades into a gentle blue under the clear sky.
# Description2: In the heart of a bustling coastal village, a dingo is seen strolling along the edge of a busy beach. The camera captures a three-quarter view from ground level, with the focus on the dingo's curious gaze towards the shoreline. The scene is illuminated by the soft, diffused light of overcast skies, lending a serene atmosphere. Behind the dingo, sunbathers and swimmers animate the sandy stretch, while colorful umbrellas and lively surf add vibrancy to the background.
# <PIL.Image.Image image mode=RGB size=1024x512>

# %%
item = random.choice(subjects200k.dataset2)
print(f"Instance: {item['instance']}")
print(f"Description1: {item['description1']}")
print(f"Description2: {item['description2']}")
item["image_pair"]
# Out:
# Instance: A high-performance motorcycle with superior cornering.
# Description1: Under a starry night sky, it is parked at the edge of a forest, its metallic sheen reflecting the moonlight and surrounded by the silhouette of tall trees.
# Description2: Under uniform, high-key lighting on a plain white backdrop, this item is captured in a three-quarter view, revealing its aerodynamic design, aggressive stance, and intricate detailing of its bodywork and components.
# <PIL.Image.Image image mode=RGB size=1024x512>
