# %%
from src.dataset import Subjects200KDataset
import random

# %%
subjects200k = Subjects200KDataset(enable_filter=True)

# %%
len(subjects200k)
# Out:
# 119967

# %%
item = random.choice(subjects200k)
print(f"Instance: {item['instance']}")
print(f"Description1: {item['description1']}")
print(f"Description2: {item['description2']}")
item["image_pair"]
# Out:
# Instance: Painting of Honfleur harbor by Monet.
# Description1: Positioned on an easel by the seaside, this item catches the golden hues of sunrise with waves crashing in the background, its colors reflecting the morning light.
# Description2: In a professional studio, this object is captured against a pristine white background under high-key lighting, highlighting its intricate brushwork and the subtle play of light and color across its surface in a front-facing angle.
# <PIL.Image.Image image mode=RGB size=1024x512>

# %%
item = random.choice(subjects200k.dataset1)
print(f"Instance: {item['instance']}")
print(f"Description1: {item['description1']}")
print(f"Description2: {item['description2']}")
item["image_pair"]
# Out:
# Instance: Hedgehog
# Description1: On a bustling city street, a hedgehog is captured from a side profile angle as it navigates along the edge of a bustling sidewalk. The photo is taken at dusk, with streetlights illuminating its path and casting subtle shadows beneath its tiny paws. The urban background is filled with blurred figures of pedestrians and distant headlights, illustrating the contrast between the city's fast pace and the hedgehog's slow and steady movement. The air is cool, suggesting a crisp autumn evening.
# ...

# %%
item = random.choice(subjects200k.dataset2)
print(f"Instance: {item['instance']}")
print(f"Description1: {item['description1']}")
print(f"Description2: {item['description2']}")
item["image_pair"]
# Out:
# Instance: Crisp, golden beverage in glass or bottle.
# Description1: On a bustling outdoor patio, lit by the warm glow of late afternoon sun, it sits glistening with condensation, amidst laughing patrons and live music.
# Description2: In a professional studio, against a plain white background, it is shot with uniform, high-key lighting from the front, highlighting its clear, slightly effervescent appearance with no shadows present.
# <PIL.Image.Image image mode=RGB size=1024x512>
